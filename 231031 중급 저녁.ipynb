# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

df = pd.read_csv('/content/drive/MyDrive/sonar3.csv', header=None)
# print(df.head(10))
# print(df.info())
# print(df.describe())
# print(df[60].value_counts())

# plt.figure(figsize=(12, 12))
# sns.heatmap(df.corr(), vmax=0.7, cmap='coolwarm', linewidths=0.5)
# 46, 47번 컬럼 간의 히스토그램 그래프
# plt.hist(x=[df[47], df[46]], bins=50, histtype='stepfilled')

# 45번과 47번 컬럼에 대한 상관관계 계산
# correlation = df[[46, 47]].corr()

# 상관관계 히트맵 그리기
# plt.figure(figsize=(8, 6))
# sns.heatmap(correlation, annot=True, cmap='coolwarm', square=True)
# plt.legend()
# plt.tight_layout()

#산점도
# sns.pairplot(df[[46, 47, 60]], hue=60, plot_kws={'alpha':0.3})
# plt.show()

x = df.iloc[:, 0:60]
y = df.iloc[:,60]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True)
# print(y_train.value_counts())
# print(x_train[50].value_counts())
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, input_dim=60, activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x, y, epochs=50, batch_size=16)

loss, accuracy = model.evaluate(x_test, y_test)
print('test test:', loss)
print('test accuracy:', accuracy)
# plt.plot(history.history['loss'])
# plt.plot(score)
# plt.xlabel('epochs')
# plt.ylabel('loss')
# plt.show()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 3ms/step - loss: 0.6847 - accuracy: 0.5337
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.5385
# Epoch 3/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6522 - accuracy: 0.6346
# Epoch 4/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.6587
# Epoch 5/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7692
# Epoch 6/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5531 - accuracy: 0.7404
# Epoch 7/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4903 - accuracy: 0.7981
# Epoch 8/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7933
# Epoch 9/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.7981
# Epoch 10/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8125
# Epoch 11/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8558
# Epoch 12/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3451 - accuracy: 0.8510
# Epoch 13/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8365
# Epoch 14/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3035 - accuracy: 0.8846
# Epoch 15/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2819 - accuracy: 0.8798
# Epoch 16/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9038
# Epoch 17/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2459 - accuracy: 0.9183
# Epoch 18/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2733 - accuracy: 0.8894
# Epoch 19/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.8942
# Epoch 20/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.8654
# Epoch 21/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9423
# Epoch 22/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2521 - accuracy: 0.8894
# Epoch 23/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1897 - accuracy: 0.9375
# Epoch 24/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9519
# Epoch 25/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1484 - accuracy: 0.9519
# Epoch 26/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1384 - accuracy: 0.9615
# Epoch 27/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9712
# Epoch 28/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9663
# Epoch 29/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9663
# Epoch 30/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.9663
# Epoch 31/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1255 - accuracy: 0.9471
# Epoch 32/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9952
# Epoch 33/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9856
# Epoch 34/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9808
# Epoch 35/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9856
# Epoch 36/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 0.9904
# Epoch 37/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9904
# Epoch 38/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 0.9952
# Epoch 39/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9904
# Epoch 40/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9856
# Epoch 41/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 42/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 43/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 44/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9952
# Epoch 45/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 46/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 47/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 48/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 49/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 50/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# test test: 0.002557892119511962
# test accuracy: 1.0

# %%
model.save('/content/drive/MyDrive/my_model.hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save('/content/drive/MyDrive/my_model.keras')

# %%
model.save('/content/drive/MyDrive/my_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('/content/drive/MyDrive/my_model.h5')
